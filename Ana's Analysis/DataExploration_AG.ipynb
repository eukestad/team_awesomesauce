# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Airport_Data_2019 = "2019_T_T100_MARKET_ALL_CARRIER.csv"
Airport_Data_2020 = "2020_T_T100_MARKET_ALL_CARRIER.csv"

# %%
Airport_Data_2019_df = pd.read_csv(Airport_Data_2019)
Airport_Data_2020_df = pd.read_csv(Airport_Data_2020)

# %%
Airport_Data_2019_df.count()
# Out:
# PASSENGERS             321168
# CARRIER                321168
# CARRIER_NAME           321168
# ORIGIN                 321168
# ORIGIN_CITY_NAME       321168
# ORIGIN_STATE_ABR       293012
# ORIGIN_COUNTRY         321168
# ORIGIN_COUNTRY_NAME    321168
# DEST                   321168
# DEST_CITY_NAME         321168
# DEST_STATE_ABR         292196
# DEST_COUNTRY           321168
# DEST_COUNTRY_NAME      321168
# YEAR                   321168
# QUARTER                321168
# MONTH                  321168
# DISTANCE_GROUP         321168
# CLASS                  321168
# DATA_SOURCE            321168
# Unnamed: 19                 0
# dtype: int64

# %%
Airport_Data_2020_df.count()
# Out:
# PASSENGERS             139546
# CARRIER                139546
# CARRIER_NAME           139542
# ORIGIN                 139546
# ORIGIN_CITY_NAME       139546
# ORIGIN_STATE_ABR       128557
# ORIGIN_COUNTRY         139546
# ORIGIN_COUNTRY_NAME    139546
# DEST                   139546
# DEST_CITY_NAME         139546
# DEST_STATE_ABR         128200
# DEST_COUNTRY           139546
# DEST_COUNTRY_NAME      139546
# YEAR                   139546
# QUARTER                139546
# MONTH                  139546
# DISTANCE_GROUP         139546
# CLASS                  139546
# DATA_SOURCE            139546
# Unnamed: 19                 0
# dtype: int64

# %%
df_list = [Airport_Data_2019_df,Airport_Data_2020_df]
Flights_df = pd.concat(df_list)
Flights_df
# Out:
#         PASSENGERS CARRIER            CARRIER_NAME ORIGIN  \
# 0              0.0      EM    Empire Airlines Inc.    ABQ
# 1              0.0      EM    Empire Airlines Inc.    ABQ
# 2              0.0      EM    Empire Airlines Inc.    AFW
# 3              0.0      EM    Empire Airlines Inc.    AFW
# 4              0.0      EM    Empire Airlines Inc.    AFW
# ...            ...     ...                     ...    ...
# 139541     72962.0      HA  Hawaiian Airlines Inc.    HNL
# 139542     84608.0      DL    Delta Air Lines Inc.    ATL
# 139543     85349.0      DL    Delta Air Lines Inc.    MCO
# 139544     86715.0      DL    Delta Air Lines Inc.    ATL
# 139545     91173.0      DL    Delta Air Lines Inc.    MCO
#
#              ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_COUNTRY  \
# 0             Albuquerque, NM               NM             US
# 1             Albuquerque, NM               NM             US
# 2       Dallas/Fort Worth, TX               TX             US
# 3       Dallas/Fort Worth, TX               TX             US
# 4       Dallas/Fort Worth, TX               TX             US
# ...                       ...              ...            ...
# 139541           Honolulu, HI               HI             US
# 139542            Atlanta, GA               GA             US
# 139543            Orlando, FL               FL             US
# 139544            Atlanta, GA               GA             US
# 139545            Orlando, FL               FL             US
#
#        ORIGIN_COUNTRY_NAME DEST      DEST_CITY_NAME DEST_STATE_ABR  \
# 0            United States  DRO         Durango, CO             CO
# 1            United States  FMN      Farmington, NM             NM
# 2            United States  ICT         Wichita, KS             KS
# 3            United States  LBB         Lubbock, TX             TX
# 4            United States  MAF  Midland/Odessa, TX             TX
# ...                    ...  ...                 ...            ...
# 139541       United States  OGG         Kahului, HI             HI
# 139542       United States  MCO         Orlando, FL             FL
# 139543       United States  ATL         Atlanta, GA             GA
# 139544       United States  MCO         Orlando, FL             FL
# 139545       United States  ATL         Atlanta, GA             GA
#
#        DEST_COUNTRY DEST_COUNTRY_NAME  YEAR  QUARTER  MONTH  DISTANCE_GROUP  \
# 0                US     United States  2019        1      3               1
# 1                US     United States  2019        1      3               1
# 2                US     United States  2019        1      3               1
# 3                US     United States  2019        1      3               1
# 4                US     United States  2019        1      3               1
# ...             ...               ...   ...      ...    ...             ...
# 139541           US     United States  2020        1      1               1
# 139542           US     United States  2020        1      2               1
# 139543           US     United States  2020        1      2               1
# 139544           US     United States  2020        1      1               1
# 139545           US     United States  2020        1      1               1
#
#        CLASS DATA_SOURCE  Unnamed: 19
# 0          G          DU          NaN
# 1          G          DU          NaN
# 2          G          DU          NaN
# 3          G          DU          NaN
# 4          G          DU          NaN
# ...      ...         ...          ...
# 139541     F          DU          NaN
# 139542     F          DU          NaN
# 139543     F          DU          NaN
# 139544     F          DU          NaN
# 139545     F          DU          NaN
#
# [460714 rows x 20 columns]

# %%
 # Airline name as new index
Airline_index = Flights_df.set_index("CARRIER_NAME")
Airline_index.head()
# Out:
#                       PASSENGERS CARRIER ORIGIN       ORIGIN_CITY_NAME  \
# CARRIER_NAME
# Empire Airlines Inc.         0.0      EM    ABQ        Albuquerque, NM
# Empire Airlines Inc.         0.0      EM    ABQ        Albuquerque, NM
# Empire Airlines Inc.         0.0      EM    AFW  Dallas/Fort Worth, TX
# Empire Airlines Inc.         0.0      EM    AFW  Dallas/Fort Worth, TX
# Empire Airlines Inc.         0.0      EM    AFW  Dallas/Fort Worth, TX
#
#                      ORIGIN_STATE_ABR ORIGIN_COUNTRY ORIGIN_COUNTRY_NAME DEST  \
# CARRIER_NAME
# Empire Airlines Inc.               NM             US       United States  DRO
# Empire Airlines Inc.               NM             US       United States  FMN
# Empire Airlines Inc.               TX             US       United States  ICT
# Empire Airlines Inc.               TX             US       United States  LBB
# Empire Airlines Inc.               TX             US       United States  MAF
#
#                           DEST_CITY_NAME DEST_STATE_ABR DEST_COUNTRY  \
# CARRIER_NAME
# Empire Airlines Inc.         Durango, CO             CO           US
# Empire Airlines Inc.      Farmington, NM             NM           US
# Empire Airlines Inc.         Wichita, KS             KS           US
# Empire Airlines Inc.         Lubbock, TX             TX           US
# Empire Airlines Inc.  Midland/Odessa, TX             TX           US
#
#                      DEST_COUNTRY_NAME  YEAR  QUARTER  MONTH  DISTANCE_GROUP  \
# CARRIER_NAME
# Empire Airlines Inc.     United States  2019        1      3               1
# Empire Airlines Inc.     United States  2019        1      3               1
# Empire Airlines Inc.     United States  2019        1      3               1
# Empire Airlines Inc.     United States  2019        1      3               1
# Empire Airlines Inc.     United States  2019        1      3               1
#
#                      CLASS DATA_SOURCE  Unnamed: 19
# CARRIER_NAME
# Empire Airlines Inc.     G          DU          NaN
# Empire Airlines Inc.     G          DU          NaN
# Empire Airlines Inc.     G          DU          NaN
# Empire Airlines Inc.     G          DU          NaN
# Empire Airlines Inc.     G          DU          NaN
