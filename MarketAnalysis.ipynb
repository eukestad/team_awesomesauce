# %% [markdown]
# ## TEAM AWESOMESAUCE
# #### How has the COIVD-19 Pandemic affeted Domestic and International Flights from 2019 and 2020
#
# #### The data obtained was from 1 January 2019 through 31 July 2020. As we get more data we will update the statistics
#
# #### Team Hypothesis: COVID-19 drastically effect all flights but had a bigger impact Internationally as rest of the world took the disease more serious than the United States

# %% [markdown]
# ## Observation and Insights
# #### 1. Covid-19 effected the world and in our project, flights (foregin and domestic), in a major way. The overall data showed that all flights were effected but as you look closer you can possibly see how the rest of the world may have taken the disease a little more serious than the United States
# #### 2. While there was a instant effect as the world went into lockdown, slowly but surely based on the data, it seems that things are getting back to normal. Internationally it seems that they are openining up the airways at a slower pace than the United States.
# #### 3. The Implementation of quarantining as you enter countries may also be a reason for the slow progression of more International Flights. Some states in the United States have tried to implement the rules but mostly countries outside of the United States still have these rules in place and so while all flights are gradually on the uptick, it will be a slower movement for International Flights to get back to or surpass numbers in the past.

# %%
# !pip install seaborn

# %%
# Dependencies and Setup

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
import seaborn as sns

# Select CSV file - Clean data
Airport_Data = "output_data/flightdata.csv"

# Read CSV file
Flights_df = pd.read_csv(Airport_Data)

# %%
# Create a column in the Flights DataFrame to join Year and Month 

Flights_df['DATE'] = [date(year, month, 1) for year, month in zip(Flights_df['YEAR'], Flights_df['MONTH'])]
Flights_df
# Out:
#            UNIQUE_CARRIER_NAME ORIGIN                ORIGIN_CITY_NAME  \
# 0       Southwest Airlines Co.    PBI  West Palm Beach/Palm Beach, FL
# 1       Southwest Airlines Co.    PHL                Philadelphia, PA
# 2       Southwest Airlines Co.    PVD                  Providence, RI
# 3       Southwest Airlines Co.    RIC                    Richmond, VA
# 4       Southwest Airlines Co.    RIC                    Richmond, VA
# ...                        ...    ...                             ...
# 235100  Hawaiian Airlines Inc.    HNL                    Honolulu, HI
# 235101    Delta Air Lines Inc.    ATL                     Atlanta, GA
# 235102    Delta Air Lines Inc.    MCO                     Orlando, FL
# 235103    Delta Air Lines Inc.    ATL                     Atlanta, GA
# 235104    Delta Air Lines Inc.    MCO                     Orlando, FL
#
#        ORIGIN_STATE_ABR ORIGIN_STATE_NM ORIGIN_COUNTRY ORIGIN_COUNTRY_NAME  \
# 0                    FL         Florida             US       United States
# 1                    PA    Pennsylvania             US       United States
# 2                    RI    Rhode Island             US       United States
# 3                    VA        Virginia             US       United States
# 4                    VA        Virginia             US       United States
# ...                 ...             ...            ...                 ...
# 235100               HI          Hawaii             US       United States
# 235101               GA         Georgia             US       United States
# 235102               FL         Florida             US       United States
# 235103               GA         Georgia             US       United States
# 235104               FL         Florida             US       United States
#
#         ORIGIN_WAC DEST DEST_CITY_NAME  ... DEST_WAC  YEAR QUARTER MONTH  \
# 0               33  DAL     Dallas, TX  ...       74  2019       2     6
# 1               23  GEG    Spokane, WA  ...       93  2019       2     6
# 2               15  ATL    Atlanta, GA  ...       34  2019       2     6
# 3               38  DEN     Denver, CO  ...       82  2019       2     6
# 4               38  LAS  Las Vegas, NV  ...       85  2019       2     6
# ...            ...  ...            ...  ...      ...   ...     ...   ...
# 235100           2  OGG    Kahului, HI  ...        2  2020       1     1
# 235101          34  MCO    Orlando, FL  ...       33  2020       1     2
# 235102          33  ATL    Atlanta, GA  ...       34  2020       1     2
# 235103          34  MCO    Orlando, FL  ...       33  2020       1     1
# 235104          33  ATL    Atlanta, GA  ...       34  2020       1     1
#
#         DISTANCE_GROUP  PASSENGERS  DISTANCE  CLASS  flight        DATE
# 0                    3         0.0    1091.0      F  PBIDAL  2019-06-01
# 1                    5         0.0    2155.0      F  PHLGEG  2019-06-01
# 2                    2         0.0     903.0      F  PVDATL  2019-06-01
# 3                    3         0.0    1482.0      F  RICDEN  2019-06-01
# 4                    5         0.0    2086.0      F  RICLAS  2019-06-01
# ...                ...         ...       ...    ...     ...         ...
# 235100               1     72962.0     100.0      F  HNLOGG  2020-01-01
# 235101               1     84608.0     404.0      F  ATLMCO  2020-02-01
# 235102               1     85349.0     404.0      F  MCOATL  2020-02-01
# 235103               1     86715.0     404.0      F  ATLMCO  2020-01-01
# 235104               1     91173.0     404.0      F  MCOATL  2020-01-01
#
# [235105 rows x 24 columns]

# %%
# To set the date column as the index, so it plots chronologically:

Flights_df["DATE"] = pd.to_datetime(Flights_df["DATE"])
Flights_df.set_index("DATE", inplace=True)
Flights_df
# Out:
#                UNIQUE_CARRIER_NAME ORIGIN                ORIGIN_CITY_NAME  \
# DATE
# 2019-06-01  Southwest Airlines Co.    PBI  West Palm Beach/Palm Beach, FL
# 2019-06-01  Southwest Airlines Co.    PHL                Philadelphia, PA
# 2019-06-01  Southwest Airlines Co.    PVD                  Providence, RI
# 2019-06-01  Southwest Airlines Co.    RIC                    Richmond, VA
# 2019-06-01  Southwest Airlines Co.    RIC                    Richmond, VA
# ...                            ...    ...                             ...
# 2020-01-01  Hawaiian Airlines Inc.    HNL                    Honolulu, HI
# 2020-02-01    Delta Air Lines Inc.    ATL                     Atlanta, GA
# 2020-02-01    Delta Air Lines Inc.    MCO                     Orlando, FL
# 2020-01-01    Delta Air Lines Inc.    ATL                     Atlanta, GA
# 2020-01-01    Delta Air Lines Inc.    MCO                     Orlando, FL
#
#            ORIGIN_STATE_ABR ORIGIN_STATE_NM ORIGIN_COUNTRY  \
# DATE
# 2019-06-01               FL         Florida             US
# 2019-06-01               PA    Pennsylvania             US
# 2019-06-01               RI    Rhode Island             US
# 2019-06-01               VA        Virginia             US
# 2019-06-01               VA        Virginia             US
# ...                     ...             ...            ...
# 2020-01-01               HI          Hawaii             US
# 2020-02-01               GA         Georgia             US
# 2020-02-01               FL         Florida             US
# 2020-01-01               GA         Georgia             US
# 2020-01-01               FL         Florida             US
#
#            ORIGIN_COUNTRY_NAME  ORIGIN_WAC DEST DEST_CITY_NAME  ...  \
# DATE                                                            ...
# 2019-06-01       United States          33  DAL     Dallas, TX  ...
# 2019-06-01       United States          23  GEG    Spokane, WA  ...
# 2019-06-01       United States          15  ATL    Atlanta, GA  ...
# 2019-06-01       United States          38  DEN     Denver, CO  ...
# 2019-06-01       United States          38  LAS  Las Vegas, NV  ...
# ...                        ...         ...  ...            ...  ...
# 2020-01-01       United States           2  OGG    Kahului, HI  ...
# 2020-02-01       United States          34  MCO    Orlando, FL  ...
# 2020-02-01       United States          33  ATL    Atlanta, GA  ...
# 2020-01-01       United States          34  MCO    Orlando, FL  ...
# 2020-01-01       United States          33  ATL    Atlanta, GA  ...
#
#            DEST_COUNTRY_NAME DEST_WAC  YEAR QUARTER  MONTH  DISTANCE_GROUP  \
# DATE
# 2019-06-01     United States       74  2019       2      6               3
# 2019-06-01     United States       93  2019       2      6               5
# 2019-06-01     United States       34  2019       2      6               2
# 2019-06-01     United States       82  2019       2      6               3
# 2019-06-01     United States       85  2019       2      6               5
# ...                      ...      ...   ...     ...    ...             ...
# 2020-01-01     United States        2  2020       1      1               1
# 2020-02-01     United States       33  2020       1      2               1
# 2020-02-01     United States       34  2020       1      2               1
# 2020-01-01     United States       33  2020       1      1               1
# 2020-01-01     United States       34  2020       1      1               1
#
#             PASSENGERS  DISTANCE  CLASS  flight
# DATE
# 2019-06-01         0.0    1091.0      F  PBIDAL
# 2019-06-01         0.0    2155.0      F  PHLGEG
# 2019-06-01         0.0     903.0      F  PVDATL
# 2019-06-01         0.0    1482.0      F  RICDEN
# 2019-06-01         0.0    2086.0      F  RICLAS
# ...                ...       ...    ...     ...
# 2020-01-01     72962.0     100.0      F  HNLOGG
# 2020-02-01     84608.0     404.0      F  ATLMCO
# 2020-02-01     85349.0     404.0      F  MCOATL
# 2020-01-01     86715.0     404.0      F  ATLMCO
# 2020-01-01     91173.0     404.0      F  MCOATL
#
# [235105 rows x 23 columns]

# %%
# Create DataFrame to show all International Flights

int_df = Flights_df[Flights_df['DEST_COUNTRY']!=Flights_df['ORIGIN_COUNTRY']].copy()
int_df
# Out:
#                                   UNIQUE_CARRIER_NAME ORIGIN  \
# DATE
# 2019-01-01                   Tropic Ocean Airways LLC    FLL
# 2019-01-01                                   Cape Air    EIS
# 2019-01-01                                   Cape Air    STT
# 2019-04-01  Commutair Aka Champlain Enterprises, Inc.    ALB
# 2019-04-01  Commutair Aka Champlain Enterprises, Inc.    YUL
# ...                                               ...    ...
# 2020-01-01                    Virgin Atlantic Airways    LHR
# 2020-02-01                        British Airways Plc    LHR
# 2020-02-01                        British Airways Plc    JFK
# 2020-01-01                        British Airways Plc    JFK
# 2020-01-01                        British Airways Plc    LHR
#
#                              ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# DATE
# 2019-01-01                Fort Lauderdale, FL               FL
# 2019-01-01  Road Town, British Virgin Islands              NaN
# 2019-01-01               Charlotte Amalie, VI               VI
# 2019-04-01                         Albany, NY               NY
# 2019-04-01                   Montreal, Canada               QC
# ...                                       ...              ...
# 2020-01-01             London, United Kingdom              NaN
# 2020-02-01             London, United Kingdom              NaN
# 2020-02-01                       New York, NY               NY
# 2020-01-01                       New York, NY               NY
# 2020-01-01             London, United Kingdom              NaN
#
#                 ORIGIN_STATE_NM ORIGIN_COUNTRY     ORIGIN_COUNTRY_NAME  \
# DATE
# 2019-01-01              Florida             US           United States
# 2019-01-01                  NaN             VG  British Virgin Islands
# 2019-01-01  U.S. Virgin Islands             US           United States
# 2019-04-01             New York             US           United States
# 2019-04-01               Quebec             CA                  Canada
# ...                         ...            ...                     ...
# 2020-01-01                  NaN             GB          United Kingdom
# 2020-02-01                  NaN             GB          United Kingdom
# 2020-02-01             New York             US           United States
# 2020-01-01             New York             US           United States
# 2020-01-01                  NaN             GB          United Kingdom
#
#             ORIGIN_WAC DEST                     DEST_CITY_NAME  ...  \
# DATE                                                            ...
# 2019-01-01          33  BS3             Baker Bay, The Bahamas  ...
# 2019-01-01         282  STT               Charlotte Amalie, VI  ...
# 2019-01-01           4  EIS  Road Town, British Virgin Islands  ...
# 2019-04-01          22  YUL                   Montreal, Canada  ...
# 2019-04-01         941  ROC                      Rochester, NY  ...
# ...                ...  ...                                ...  ...
# 2020-01-01         493  JFK                       New York, NY  ...
# 2020-02-01         493  JFK                       New York, NY  ...
# 2020-02-01          22  LHR             London, United Kingdom  ...
# 2020-01-01          22  LHR             London, United Kingdom  ...
# 2020-01-01         493  JFK                       New York, NY  ...
#
#                  DEST_COUNTRY_NAME DEST_WAC  YEAR QUARTER  MONTH  \
# DATE
# 2019-01-01             The Bahamas      204  2019       1      1
# 2019-01-01           United States        4  2019       1      1
# 2019-01-01  British Virgin Islands      282  2019       1      1
# 2019-04-01                  Canada      941  2019       2      4
# 2019-04-01           United States       22  2019       2      4
# ...                            ...      ...   ...     ...    ...
# 2020-01-01           United States       22  2020       1      1
# 2020-02-01           United States       22  2020       1      2
# 2020-02-01          United Kingdom      493  2020       1      2
# 2020-01-01          United Kingdom      493  2020       1      1
# 2020-01-01           United States       22  2020       1      1
#
#             DISTANCE_GROUP  PASSENGERS  DISTANCE  CLASS  flight
# DATE
# 2019-01-01               1         0.0     192.0      F  FLLBS3
# 2019-01-01               1         0.0      29.0      F  EISSTT
# 2019-01-01               1         0.0      29.0      F  STTEIS
# 2019-04-01               1         0.0     188.0      F  ALBYUL
# 2019-04-01               1         0.0     254.0      F  YULROC
# ...                    ...         ...       ...    ...     ...
# 2020-01-01               7     34761.0    3452.0      F  LHRJFK
# 2020-02-01               7     43513.0    3452.0      F  LHRJFK
# 2020-02-01               7     44180.0    3452.0      F  JFKLHR
# 2020-01-01               7     45227.0    3452.0      F  JFKLHR
# 2020-01-01               7     48484.0    3452.0      F  LHRJFK
#
# [45020 rows x 23 columns]

# %%
# Create DataFrame to show all Domestic Flights

dom_df = Flights_df[Flights_df['DEST_COUNTRY']==Flights_df['ORIGIN_COUNTRY']].copy()
dom_df
# Out:
#                UNIQUE_CARRIER_NAME ORIGIN                ORIGIN_CITY_NAME  \
# DATE
# 2019-06-01  Southwest Airlines Co.    PBI  West Palm Beach/Palm Beach, FL
# 2019-06-01  Southwest Airlines Co.    PHL                Philadelphia, PA
# 2019-06-01  Southwest Airlines Co.    PVD                  Providence, RI
# 2019-06-01  Southwest Airlines Co.    RIC                    Richmond, VA
# 2019-06-01  Southwest Airlines Co.    RIC                    Richmond, VA
# ...                            ...    ...                             ...
# 2020-01-01  Hawaiian Airlines Inc.    HNL                    Honolulu, HI
# 2020-02-01    Delta Air Lines Inc.    ATL                     Atlanta, GA
# 2020-02-01    Delta Air Lines Inc.    MCO                     Orlando, FL
# 2020-01-01    Delta Air Lines Inc.    ATL                     Atlanta, GA
# 2020-01-01    Delta Air Lines Inc.    MCO                     Orlando, FL
#
#            ORIGIN_STATE_ABR ORIGIN_STATE_NM ORIGIN_COUNTRY  \
# DATE
# 2019-06-01               FL         Florida             US
# 2019-06-01               PA    Pennsylvania             US
# 2019-06-01               RI    Rhode Island             US
# 2019-06-01               VA        Virginia             US
# 2019-06-01               VA        Virginia             US
# ...                     ...             ...            ...
# 2020-01-01               HI          Hawaii             US
# 2020-02-01               GA         Georgia             US
# 2020-02-01               FL         Florida             US
# 2020-01-01               GA         Georgia             US
# 2020-01-01               FL         Florida             US
#
#            ORIGIN_COUNTRY_NAME  ORIGIN_WAC DEST DEST_CITY_NAME  ...  \
# DATE                                                            ...
# 2019-06-01       United States          33  DAL     Dallas, TX  ...
# 2019-06-01       United States          23  GEG    Spokane, WA  ...
# 2019-06-01       United States          15  ATL    Atlanta, GA  ...
# 2019-06-01       United States          38  DEN     Denver, CO  ...
# 2019-06-01       United States          38  LAS  Las Vegas, NV  ...
# ...                        ...         ...  ...            ...  ...
# 2020-01-01       United States           2  OGG    Kahului, HI  ...
# 2020-02-01       United States          34  MCO    Orlando, FL  ...
# 2020-02-01       United States          33  ATL    Atlanta, GA  ...
# 2020-01-01       United States          34  MCO    Orlando, FL  ...
# 2020-01-01       United States          33  ATL    Atlanta, GA  ...
#
#            DEST_COUNTRY_NAME DEST_WAC  YEAR QUARTER  MONTH  DISTANCE_GROUP  \
# DATE
# 2019-06-01     United States       74  2019       2      6               3
# 2019-06-01     United States       93  2019       2      6               5
# 2019-06-01     United States       34  2019       2      6               2
# 2019-06-01     United States       82  2019       2      6               3
# 2019-06-01     United States       85  2019       2      6               5
# ...                      ...      ...   ...     ...    ...             ...
# 2020-01-01     United States        2  2020       1      1               1
# 2020-02-01     United States       33  2020       1      2               1
# 2020-02-01     United States       34  2020       1      2               1
# 2020-01-01     United States       33  2020       1      1               1
# 2020-01-01     United States       34  2020       1      1               1
#
#             PASSENGERS  DISTANCE  CLASS  flight
# DATE
# 2019-06-01         0.0    1091.0      F  PBIDAL
# 2019-06-01         0.0    2155.0      F  PHLGEG
# 2019-06-01         0.0     903.0      F  PVDATL
# 2019-06-01         0.0    1482.0      F  RICDEN
# 2019-06-01         0.0    2086.0      F  RICLAS
# ...                ...       ...    ...     ...
# 2020-01-01     72962.0     100.0      F  HNLOGG
# 2020-02-01     84608.0     404.0      F  ATLMCO
# 2020-02-01     85349.0     404.0      F  MCOATL
# 2020-01-01     86715.0     404.0      F  ATLMCO
# 2020-01-01     91173.0     404.0      F  MCOATL
#
# [190085 rows x 23 columns]

# %%
# Generate a bar graph showing the total number of Flights for 2019 and 2020 to show contrast

sns.catplot(x='MONTH', y='PASSENGERS', hue='YEAR', kind='bar', data=Flights_df, height=8.27, aspect=11.7/8.27);
plt.savefig("images/AllFlightCounts_2019vs2020.png")

# %% [markdown]
# ## The above graph shows how Covid-19 has effected all flights (foreign and domestic) through July 31, 2020. As the world went on lockdown it shows how flights almost came to a complete stop and how as the world opens up the amount of flights is starting getting back to where it was prior to the pandemic.

# %%
# Generate a bar graph showing the total number of Domestic Flights for 2019 and 2020 to show contrast

sns.catplot(x='MONTH', y='PASSENGERS', hue='YEAR', kind='bar', data=dom_df, height=8.27, aspect=11.7/8.27);
plt.savefig("images/DomesticFlightCounts_2019vs2020.png")

# %% [markdown]
# ## The above graph shows the contrast of Domestic Flights from 2019 through July 31, 2020. Conisistent with the overall graph this graph shows that as the Lockdown happened in March 2020 flights almost came to a hault in the United States. As well as when the rules of the Lockdown eased the numbers started to creep back up and are slowly on their way increasing as the year progresses.

# %%
# Generate a bar plot showing the total number of International Flights for 2019 and 2020 to show contrast.

sns.catplot(x='MONTH', y='PASSENGERS', hue='YEAR', kind='bar', data=int_df, height=8.27, aspect=11.7/8.27);
plt.savefig("images/InternationalFlightCounts_2019vs2020.png")

# %% [markdown]
# ## The graph above shows the contrast of International Flights from 2019 through July 31, 2020. It also shows how the pandemic has effected travel and to look deeper the reason that International Flights may be increasing at a slower rate is that other countries have harsher Lockdown rules and the implementation of quarantine rules once in a country may be the reason for this slow progression.
